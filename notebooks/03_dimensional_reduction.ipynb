# %% [markdown]
# ## **Notebook Content**
#
# Project: *Customer Prioritization Under Constraints*
#
# File: 03_dimensional_reduction.ipynb <br>
# Author: Bryan Melvida
#
# Purpose:
# - Reduce the engineered feature space while preserving behavioral structure
# - Improve cluster separability and stability for downstream segmentation
# - Enable clearer visual and metric-based assessment of clustering outcomes
#
# Input: [`customer_features.parquet`](../data/preprocessed/customer_features.parquet) <br>
#
# Output: [`customer_features_reduced.parquet`]()<br>
# Related Documentation:
#
# <br>
#
# ---
#
# <br>
